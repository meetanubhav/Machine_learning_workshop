# %% [markdown]
# <a href="https://colab.research.google.com/github/meetanubhav/OpenCV_works/blob/master/opencv2_work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
img=cv2.imread('CS166126_128X128.jpg')

# %%
print(img.shape)
# Out:
# (128, 128, 3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F6121CFB7B8>

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RBG)
plt.imshow('img')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b1855dbc8a0b> in <module>()
# ----> 1 img=cv2.cvtColor(img,cv2.COLOR_BGR2RBG)
#       2 plt.imshow('img')
#       3 plt.axis("off")
#       4 plt.show()
#
# AttributeError: module 'cv2.cv2' has no attribute 'COLOR_BGR2RBG'
